# %%
#Importing Python Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

#Importing All VI CSV's In Chronological Order:

#2020
date1 = pd.read_csv("C:/NSF-REU/Indices_Combined_Files/2020/June_18_2020_New.csv")
date2 = pd.read_csv("C:/NSF-REU/Indices_Combined_Files/2020/June_23_2020_New.csv")
date3 = pd.read_csv("C:/NSF-REU/Indices_Combined_Files/2020/June_30_2020_New.csv")
date4 = pd.read_csv("C:/NSF-REU/Indices_Combined_Files/2020/July_6_2020_New.csv")

#2021
date5 = pd.read_csv("C:/NSF-REU/Indices_Combined_Files/2021/June_16_2021.csv")
date6 = pd.read_csv("C:/NSF-REU/Indices_Combined_Files/2021/June_22_2021.csv")
date7 = pd.read_csv("C:/NSF-REU/Indices_Combined_Files/2021/June_30_2021.csv")
date8 = pd.read_csv("C:/NSF-REU/Indices_Combined_Files/2021/July_12_2021.csv")

#2022
date9 = pd.read_csv("C:/NSF-REU/Indices_Combined_Files/2022/June_15_2022.csv")
date10 = pd.read_csv("C:/NSF-REU/Indices_Combined_Files/2022/June_23_2022.csv")
date11 = pd.read_csv("C:/NSF-REU/Indices_Combined_Files/2022/June_28_2022.csv")
date12 = pd.read_csv("C:/NSF-REU/Indices_Combined_Files/2022/July_13_2022.csv")

date9 = date9.drop(columns=['id_old'])
date10 = date10.drop(columns=['id_old'])
date11 = date11.drop(columns=['id_old'])
date12 = date12.drop(columns=['id_old'])

dates = [date1, date2, date3, date4, date5, date6, date7, date8, date9, date10, date11, date12]

def feature_importance():
    for date in dates:
        x = date.drop(columns=['Plot', 'Year', "Date", 'Row', 'Range', 'left', 'top', 'right', 'bottom', 'Yld Mass(D', 'Yld Vol(Dr', 'Crop Flw(M', 'Crop Flw(V', 'Mean.Yld.bu.ac', 'X', 'Y'])
        y = date['Mean.Yld.bu.ac']
        x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.70)
        model = RandomForestRegressor(n_estimators=100) 
        model.fit(x_train, y_train)
        y_predict = model.predict(x_test)
        print("R-Squared:", r2_score(y_test, y_predict))
        importances = model.feature_importances_
        field_importance = pd.Series(importances, index=x.columns)
        field_importance.plot(kind='bar')
        plt.bar(range(len(model.feature_importances_)), model.feature_importances_)
        plt.yticks(np.arange(0, importances.max(), 0.1)) 
        plt.show()
        print(importances, "\n")

feature_importance()
# Out:
# R-Squared: 0.7080190629204133
# [0.03813234 0.01546812 0.09082689 0.01058002 0.01714961 0.00732426
#  0.0699817  0.01914809 0.09095852 0.01817204 0.02067545 0.09355858
#  0.00706016 0.01269967 0.00555523 0.02091491 0.06181767 0.39997675]
#
# R-Squared: 0.7618018465365872
# [0.09120268 0.01334791 0.02569852 0.01803592 0.02343723 0.01330997
#  0.03324743 0.02076155 0.03509859 0.03931651 0.02156529 0.03960675
#  0.01440368 0.03547104 0.01608103 0.03062613 0.10591557 0.4228742 ]
#
# R-Squared: 0.5914201544797154
# [0.01324429 0.0124202  0.02090249 0.01188975 0.01063608 0.02155
#  0.12729647 0.03826715 0.02473121 0.06478367 0.0218529  0.02366236
#  0.02322124 0.01328357 0.01438703 0.01820732 0.11727124 0.42239302]
#
# R-Squared: 0.6960673900090228
# [0.02420001 0.01660981 0.02849183 0.01479637 0.02436598 0.03232528
#  0.03525597 0.05861927 0.02847893 0.0588959  0.04772349 0.02631565
#  0.03212508 0.01862625 0.02744925 0.03823693 0.09782402 0.38965997]
#
# R-Squared: 0.5463218800714209
# ...
